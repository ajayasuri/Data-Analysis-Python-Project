# %%
# import all the essential tools needed to analyze
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib
# Out:
# Using matplotlib backend: MacOSX

# %%
# import file into project
df = pd.read_csv('Occupations by Share.csv')

# %%
df
# Out:
#      ID Major Occupation Group  \
# 0                110000-290000
# 1                110000-290000
# 2                110000-290000
# 3                110000-290000
# 4                110000-290000
# ...                        ...
# 1229             510000-530000
# 1230             510000-530000
# 1231             510000-530000
# 1232             510000-530000
# 1233             510000-530000
#
#                                  Major Occupation Group  \
# 0     Management, business, science, & arts occupations
# 1     Management, business, science, & arts occupations
# 2     Management, business, science, & arts occupations
# 3     Management, business, science, & arts occupations
# 4     Management, business, science, & arts occupations
# ...                                                 ...
# 1229  Production, Transportation, & Material Moving ...
# 1230  Production, Transportation, & Material Moving ...
# 1231  Production, Transportation, & Material Moving ...
# 1232  Production, Transportation, & Material Moving ...
# 1233  Production, Transportation, & Material Moving ...
#
#      ID Minor Occupation Group                         Minor Occupation Group  \
# 0                110000-130000  Management, business, & financial occupations
# 1                110000-130000  Management, business, & financial occupations
# 2                110000-130000  Management, business, & financial occupations
# 3                110000-130000  Management, business, & financial occupations
# 4                110000-130000  Management, business, & financial occupations
# ...                        ...                                            ...
# 1229                    530000   Transportation & Material Moving Occupations
# 1230                    530000   Transportation & Material Moving Occupations
# 1231                    530000   Transportation & Material Moving Occupations
# 1232                    530000   Transportation & Material Moving Occupations
# 1233                    530000   Transportation & Material Moving Occupations
#
#      ID Broad Occupation             Broad Occupation ID Detailed Occupation  \
# 0                 110000       Management occupations                 111021
# 1                 110000       Management occupations                 1110XX
# 2                 110000       Management occupations                 112011
# 3                 110000       Management occupations                 112021
# 4                 110000       Management occupations                 112022
# ...                  ...                          ...                    ...
# 1229       531000-536000   Transportation Occupations                 533041
# 1230              537000  Material Moving Occupations                 537051
# 1231              537000  Material Moving Occupations                 537061
# 1232              537000  Material Moving Occupations                 537062
# 1233              537000  Material Moving Occupations                 537064
#
#                                     Detailed Occupation  ID Year  Year  ...  \
# 0                         General & operations managers     2019  2019  ...
# 1                        Chief executives & legislators     2019  2019  ...
# 2                     Advertising & promotions managers     2019  2019  ...
# 3                                    Marketing managers     2019  2019  ...
# 4                                        Sales managers     2019  2019  ...
# ...                                                 ...      ...   ...  ...
# 1229                          Taxi drivers & chauffeurs     2014  2014  ...
# 1230               Industrial truck & tractor operators     2014  2014  ...
# 1231                   Cleaners of vehicles & equipment     2014  2014  ...
# 1232  Laborers & freight, stock, & material movers, ...     2014  2014  ...
# 1233                          Packers & packagers, hand     2014  2014  ...
#
#        Average Wage  Average Wage Appx MOE  Record Count  \
# 0     125300.655582           14621.223925           413
# 1     217475.300750           22016.372859           445
# 2      73657.217804           19450.981435            76
# 3     130465.070896           15683.870203           349
# 4     126227.865019           13578.775693           358
# ...             ...                    ...           ...
# 1229   49273.941568           19854.496977            11
# 1230   31990.905204            7478.661792            22
# 1231    7663.671801            3428.237179             6
# 1232   36023.528111            5738.542945           173
# 1233   14625.587041            3660.836779            56
#
#                          Slug Detailed Occupation  PUMS Industry  \
# 0                     general-operations-managers    Information
# 1                    chief-executives-legislators    Information
# 2                 advertising-promotions-managers    Information
# 3                              marketing-managers    Information
# 4                                  sales-managers    Information
# ...                                           ...            ...
# 1229                      taxi-drivers-chauffeurs    Information
# 1230           industrial-truck-tractor-operators    Information
# 1231               cleaners-of-vehicles-equipment    Information
# 1232  laborers-freight-stock-material-movers-hand    Information
# 1233                       packers-packagers-hand    Information
#
#       ID PUMS Industry  Slug PUMS Industry ID Industry Sector Industry Sector  \
# 0                   51      information-51                 51     Information
# 1                   51      information-51                 51     Information
# 2                   51      information-51                 51     Information
# 3                   51      information-51                 51     Information
# 4                   51      information-51                 51     Information
# ...                ...                 ...                ...             ...
# 1229                51      information-51                 51     Information
# 1230                51      information-51                 51     Information
# 1231                51      information-51                 51     Information
# 1232                51      information-51                 51     Information
# 1233                51      information-51                 51     Information
#
#       Slug Industry Sector
# 0              information
# 1              information
# 2              information
# 3              information
# 4              information
# ...                    ...
# 1229           information
# 1230           information
# 1231           information
# 1232           information
# 1233           information
#
# [1234 rows x 24 columns]

# %% [markdown]
# ## Analyzing and Cleaning the Data

# %%
df.columns
# Out:
# Index(['ID Major Occupation Group', 'Major Occupation Group',
#        'ID Minor Occupation Group', 'Minor Occupation Group',
#        'ID Broad Occupation', 'Broad Occupation', 'ID Detailed Occupation',
#        'Detailed Occupation', 'ID Year', 'Year', 'ID Workforce Status',
#        'Workforce Status', 'Total Population', 'Total Population MOE Appx',
#        'Average Wage', 'Average Wage Appx MOE', 'Record Count',
#        'Slug Detailed Occupation', 'PUMS Industry', 'ID PUMS Industry',
#        'Slug PUMS Industry', 'ID Industry Sector', 'Industry Sector',
#        'Slug Industry Sector'],
#       dtype='object')

# %%
df = df.drop(['ID Major Occupation Group', 'ID Minor Occupation Group', 'ID Broad Occupation', 'ID Detailed Occupation',
        'ID Year', 'ID Workforce Status',  'Workforce Status',  'Slug Detailed Occupation', 'ID PUMS Industry',
       'Slug PUMS Industry', 'ID Industry Sector', 'Record Count', 'PUMS Industry', 'Industry Sector', 'Slug Industry Sector'], axis=1)

# %%
df.Year.value_counts()
# Out:
# 2019    217
# 2018    212
# 2014    204
# 2016    203
# 2017    199
# 2015    199
# Name: Year, dtype: int64

# %%
df['Broad Occupation'].value_counts().size
# Out:
# 21

# %%
df['Broad Occupation'].value_counts()
# Out:
# Office & Administrative Support Occupations                 205
# Management occupations                                      126
# Business & financial operations occupations                 119
# Arts, design, entertainment, sports, & media occupations    114
# Computer & mathematical occupations                          82
# Sales & related occupations                                  74
# Installation, maintenance, & repair occupations              73
# Architecture & engineering occupations                       67
# Production Occupations                                       65
# Food Preparation & Serving Related Occupations               54
# Personal Care & Service Occupations                          36
# Education, Training, & Library Occupations                   35
# Construction & Extraction Occupations                        33
# Material Moving Occupations                                  27
# Life, physical, & social science occupations                 25
# Transportation Occupations                                   21
# Building & Grounds Cleaning & Maintenance Occupations        20
# Legal Occupations                                            18
# Protective service occupations                               17
# Community & Social Service Occupations                       12
# Healthcare practitioners & technical occupations             11
# Name: Broad Occupation, dtype: int64

# %%
df['Detailed Occupation'].value_counts().size
# Out:
# 301

# %%
df['Total Population'].value_counts().size
# Out:
# 1178

# %%
df['Average Wage'].value_counts().size
# Out:
# 1234

# %%
df
# Out:
#                                  Major Occupation Group  \
# 0     Management, business, science, & arts occupations
# 1     Management, business, science, & arts occupations
# 2     Management, business, science, & arts occupations
# 3     Management, business, science, & arts occupations
# 4     Management, business, science, & arts occupations
# ...                                                 ...
# 1229  Production, Transportation, & Material Moving ...
# 1230  Production, Transportation, & Material Moving ...
# 1231  Production, Transportation, & Material Moving ...
# 1232  Production, Transportation, & Material Moving ...
# 1233  Production, Transportation, & Material Moving ...
#
#                              Minor Occupation Group  \
# 0     Management, business, & financial occupations
# 1     Management, business, & financial occupations
# 2     Management, business, & financial occupations
# 3     Management, business, & financial occupations
# 4     Management, business, & financial occupations
# ...                                             ...
# 1229   Transportation & Material Moving Occupations
# 1230   Transportation & Material Moving Occupations
# 1231   Transportation & Material Moving Occupations
# 1232   Transportation & Material Moving Occupations
# 1233   Transportation & Material Moving Occupations
#
#                  Broad Occupation  \
# 0          Management occupations
# 1          Management occupations
# 2          Management occupations
# 3          Management occupations
# 4          Management occupations
# ...                           ...
# 1229   Transportation Occupations
# 1230  Material Moving Occupations
# 1231  Material Moving Occupations
# 1232  Material Moving Occupations
# 1233  Material Moving Occupations
#
#                                     Detailed Occupation  Year  \
# 0                         General & operations managers  2019
# 1                        Chief executives & legislators  2019
# 2                     Advertising & promotions managers  2019
# 3                                    Marketing managers  2019
# 4                                        Sales managers  2019
# ...                                                 ...   ...
# 1229                          Taxi drivers & chauffeurs  2014
# 1230               Industrial truck & tractor operators  2014
# 1231                   Cleaners of vehicles & equipment  2014
# 1232  Laborers & freight, stock, & material movers, ...  2014
# 1233                          Packers & packagers, hand  2014
#
#       Total Population  Total Population MOE Appx   Average Wage  \
# 0                38581                4821.767581  125300.655582
# 1                40010                4910.229176  217475.300750
# 2                 7167                2078.419474   73657.217804
# 3                33415                4487.429730  130465.070896
# 4                37472                4751.979483  126227.865019
# ...                ...                        ...            ...
# 1229              1352                 902.736536   49273.941568
# 1230              3017                1348.521148   31990.905204
# 1231               844                 713.254763    7663.671801
# 1232             17769                3272.493949   36023.528111
# 1233              6451                1971.870239   14625.587041
#
#       Average Wage Appx MOE
# 0              14621.223925
# 1              22016.372859
# 2              19450.981435
# 3              15683.870203
# 4              13578.775693
# ...                     ...
# 1229           19854.496977
# 1230            7478.661792
# 1231            3428.237179
# 1232            5738.542945
# 1233            3660.836779
#
# [1234 rows x 9 columns]

# %%
df = df.drop(['Major Occupation Group', 'Minor Occupation Group', 'Detailed Occupation'], axis=1)
#BO = BO.groupby(['Year', 'Broad Occupation']).agg({'Total Population': ['mean']}).unstack().plot()
df
# Out:
#                  Broad Occupation  Year  Total Population  \
# 0          Management occupations  2019             38581
# 1          Management occupations  2019             40010
# 2          Management occupations  2019              7167
# 3          Management occupations  2019             33415
# 4          Management occupations  2019             37472
# ...                           ...   ...               ...
# 1229   Transportation Occupations  2014              1352
# 1230  Material Moving Occupations  2014              3017
# 1231  Material Moving Occupations  2014               844
# 1232  Material Moving Occupations  2014             17769
# 1233  Material Moving Occupations  2014              6451
#
#       Total Population MOE Appx   Average Wage  Average Wage Appx MOE
# 0                   4821.767581  125300.655582           14621.223925
# 1                   4910.229176  217475.300750           22016.372859
# 2                   2078.419474   73657.217804           19450.981435
# 3                   4487.429730  130465.070896           15683.870203
# 4                   4751.979483  126227.865019           13578.775693
# ...                         ...            ...                    ...
# 1229                 902.736536   49273.941568           19854.496977
# 1230                1348.521148   31990.905204            7478.661792
# 1231                 713.254763    7663.671801            3428.237179
# 1232                3272.493949   36023.528111            5738.542945
# 1233                1971.870239   14625.587041            3660.836779
#
# [1234 rows x 6 columns]

# %%
df = df.groupby(['Broad Occupation', 'Year']).mean().reset_index()

# %%
df
# Out:
#                            Broad Occupation  Year  Total Population  \
# 0    Architecture & engineering occupations  2014      10076.454545
# 1    Architecture & engineering occupations  2015       9095.636364
# 2    Architecture & engineering occupations  2016      10253.100000
# 3    Architecture & engineering occupations  2017       9252.545455
# 4    Architecture & engineering occupations  2018       8773.583333
# ..                                      ...   ...               ...
# 121              Transportation Occupations  2015       4846.333333
# 122              Transportation Occupations  2016       5711.666667
# 123              Transportation Occupations  2017       4527.333333
# 124              Transportation Occupations  2018       4555.666667
# 125              Transportation Occupations  2019       2343.600000
#
#      Total Population MOE Appx  Average Wage  Average Wage Appx MOE
# 0                  1900.775375  81919.179814           18796.434066
# 1                  1867.250435  84428.708032           20855.260072
# 2                  1909.234311  92439.200195           27838.201249
# 3                  1812.064970  86438.588842           18358.517789
# 4                  1823.935951  86668.326529           21682.393794
# ..                         ...           ...                    ...
# 121                1461.892453  45180.982232           24466.209955
# 122                1609.104836  45416.724465           11739.555301
# 123                1395.781502  83827.313547           54961.853471
# 124                1400.343224  63688.205212           27966.859388
# 125                 986.303763  80015.354539           55279.117200
#
# [126 rows x 6 columns]

# %%
df.iloc[df['Total Population'].argmax()]
# Out:
# Broad Occupation             Arts, design, entertainment, sports, & media o...
# Year                                                                      2015
# Total Population                                                       32282.8
# Total Population MOE Appx                                              3870.73
# Average Wage                                                           64109.1
# Average Wage Appx MOE                                                  14645.3
# Name: 7, dtype: object

# %%
df.iloc[df['Average Wage'].argmax()]
# Out:
# Broad Occupation             Legal Occupations
# Year                                      2018
# Total Population                       4111.67
# Total Population MOE Appx              1434.18
# Average Wage                            136318
# Average Wage Appx MOE                  32474.9
# Name: 70, dtype: object

# %%
df.iloc[df['Total Population'].argmin()]
# Out:
# Broad Occupation             Community & Social Service Occupations
# Year                                                           2015
# Total Population                                              645.5
# Total Population MOE Appx                                   623.325
# Average Wage                                                68210.2
# Average Wage Appx MOE                                       72723.8
# Name: 25, dtype: object

# %%
df.iloc[df['Average Wage'].argmin()]
# Out:
# Broad Occupation             Food Preparation & Serving Related Occupations
# Year                                                                   2014
# Total Population                                                     3360.5
# Total Population MOE Appx                                           1164.39
# Average Wage                                                        15267.2
# Average Wage Appx MOE                                               13184.5
# Name: 48, dtype: object

# %% [markdown]
# ## Data Vizulaization Charts

# %% [markdown]
# ### Population Change Over the Years  Per Occupation

# %%
for title, group in df.groupby('Broad Occupation'):
    group.plot(x='Year', y='Total Population', kind='bar', title=title)
# Out:
# /Users/AJ/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:328: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)

# %% [markdown]
# ### Average Wage Change Over the Years Per Occupation

# %%
for title, group in df.groupby('Broad Occupation'):
    group.plot(x='Year', y='Average Wage', kind='bar', title=title)

# %% [markdown]
# ### AVG Wage/Population Change Comparison Per Occupation

# %%
for title, group in df.groupby('Broad Occupation'):
    group.plot(x='Year', y=['Total Population','Average Wage'], kind='bar', title=title)
# Out:
# /Users/AJ/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:328: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)

# %% [markdown]
# ### AVG Wage/Population Change Comparison with Scatter Plot

# %%
for title, group in df.groupby('Broad Occupation'):
    group.plot(x='Average Wage', y='Total Population', kind='scatter', title=title)
