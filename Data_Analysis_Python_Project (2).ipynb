# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Occupations by Share.csv')

# %%
df
# Out:
#      ID Major Occupation Group  \
# 0                110000-290000
# 1                110000-290000
# 2                110000-290000
# 3                110000-290000
# 4                110000-290000
# ...                        ...
# 1229             510000-530000
# 1230             510000-530000
# 1231             510000-530000
# 1232             510000-530000
# 1233             510000-530000
#
#                                  Major Occupation Group  \
# 0     Management, business, science, & arts occupations
# 1     Management, business, science, & arts occupations
# 2     Management, business, science, & arts occupations
# 3     Management, business, science, & arts occupations
# 4     Management, business, science, & arts occupations
# ...                                                 ...
# 1229  Production, Transportation, & Material Moving ...
# 1230  Production, Transportation, & Material Moving ...
# 1231  Production, Transportation, & Material Moving ...
# ...

# %%
df.columns
# Out:
# Index(['ID Major Occupation Group', 'Major Occupation Group',
#        'ID Minor Occupation Group', 'Minor Occupation Group',
#        'ID Broad Occupation', 'Broad Occupation', 'ID Detailed Occupation',
#        'Detailed Occupation', 'ID Year', 'Year', 'ID Workforce Status',
#        'Workforce Status', 'Total Population', 'Total Population MOE Appx',
#        'Average Wage', 'Average Wage Appx MOE', 'Record Count',
#        'Slug Detailed Occupation', 'PUMS Industry', 'ID PUMS Industry',
#        'Slug PUMS Industry', 'ID Industry Sector', 'Industry Sector',
#        'Slug Industry Sector'],
#       dtype='object')

# %%
df = df.drop(['ID Major Occupation Group', 'ID Minor Occupation Group', 'ID Broad Occupation', 'ID Detailed Occupation',
        'ID Year', 'ID Workforce Status',  'Workforce Status',  'Slug Detailed Occupation', 'ID PUMS Industry',
       'Slug PUMS Industry', 'ID Industry Sector', 'Record Count', 'PUMS Industry', 'Industry Sector', 'Slug Industry Sector'], axis=1)

# %%
df.Year.value_counts()
# Out:
# 2019    217
# 2018    212
# 2014    204
# 2016    203
# 2017    199
# 2015    199
# Name: Year, dtype: int64

# %%
df['Broad Occupation'].value_counts().size
# Out:
# 21

# %%
df
# Out:
#                                  Major Occupation Group  \
# 0     Management, business, science, & arts occupations
# 1     Management, business, science, & arts occupations
# 2     Management, business, science, & arts occupations
# 3     Management, business, science, & arts occupations
# 4     Management, business, science, & arts occupations
# ...                                                 ...
# 1229  Production, Transportation, & Material Moving ...
# 1230  Production, Transportation, & Material Moving ...
# 1231  Production, Transportation, & Material Moving ...
# 1232  Production, Transportation, & Material Moving ...
# 1233  Production, Transportation, & Material Moving ...
#
#                              Minor Occupation Group  \
# 0     Management, business, & financial occupations
# 1     Management, business, & financial occupations
# 2     Management, business, & financial occupations
# 3     Management, business, & financial occupations
# ...

# %%
# %matplotlib
BO = df.drop(['Major Occupation Group', 'Minor Occupation Group', 'Detailed Occupation'], axis=1)
#BO = BO.groupby(['Broad Occupation', 'Year']).reset_index()
BO = BO.groupby(['Year', 'Broad Occupation']).agg({'Total Population': ['mean']}).unstack().plot(color=colors[key])
BO
# Out:
# Using matplotlib backend: MacOSX
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-149-c37cf9ca6758> in <module>
#       2 BO = df.drop(['Major Occupation Group', 'Minor Occupation Group', 'Detailed Occupation'], axis=1)
#       3 #BO = BO.groupby(['Broad Occupation', 'Year']).reset_index()
# ----> 4 BO = BO.groupby(['Year', 'Broad Occupation']).agg({'Total Population': ['mean']}).unstack().plot(color=colors[key])
#       5 BO
#
# NameError: name 'colors' is not defined

# %%
#fig, axes = plt.subplots(figsize=(126,4))
#BO.groupby(['Year', 'Broad Occupation']).count()['Total Population'].unstack().plot
BO.plot(x='Year', y= ['Total Population'], figsize=(126,4))
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
df
# Out:
#                                  Major Occupation Group  \
# 0     Management, business, science, & arts occupations
# 1     Management, business, science, & arts occupations
# 2     Management, business, science, & arts occupations
# 3     Management, business, science, & arts occupations
# 4     Management, business, science, & arts occupations
# ...                                                 ...
# 1229  Production, Transportation, & Material Moving ...
# 1230  Production, Transportation, & Material Moving ...
# 1231  Production, Transportation, & Material Moving ...
# 1232  Production, Transportation, & Material Moving ...
# 1233  Production, Transportation, & Material Moving ...
#
#                              Minor Occupation Group  \
# 0     Management, business, & financial occupations
# 1     Management, business, & financial occupations
# 2     Management, business, & financial occupations
# 3     Management, business, & financial occupations
# ...

# %%
df_BO = df.groupby('Year').mean()

# %%
df_BO.plot(x= 'Broad Occupation', y= 'Total Population', kind= 'bar')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Broad Occupation'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-75-5db14e6c7825> in <module>
# ...
